# %%
import pandas as pd
from flask import jsonify

# %%
df=pd.read_csv("../Resources/austin_housing_reduced.csv")

# %%
variable="yearBuilt"
y=df["latestPrice"].to_list
x=df[variable].to_list()
jsonify(y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/ym/m29479k14ln__3q0ss4d44300000gn/T/ipykernel_7040/912019325.py in <module>
#       2 y=df["latestPrice"].to_list
#       3 x=df[variable].to_list()
# ----> 4 jsonify(y)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/flask/json/__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# /Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/werkzeug/local.py in __getattr__(self, name)
#     345         if name == "__members__":
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# /Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/werkzeug/local.py in _get_current_object(self)
#     304         """
#     305         if not hasattr(self.__local, "__release_local__"):
# --> 306             return self.__local()
#     307         try:
#     308             return getattr(self.__local, self.__name__)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/flask/globals.py in _find_app()
#      50     top = _app_ctx_stack.top
#      51     if top is None:
# ---> 52         raise RuntimeError(_app_ctx_err_msg)
#      53     return top.app
#      54
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.
